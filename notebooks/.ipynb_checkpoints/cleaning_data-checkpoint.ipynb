# %%
import pandas as pd
import chardet

# %%
df = pd.read_csv('../data/raw/sales_data.csv', parse_dates=['InvoiceDate'] ,encoding='ISO-8859-1')
df = df.dropna(subset=['CustomerID'])
df.to_csv("../data/processed/cleaned_sales_data.csv", index=False)
